# %%
CREATE DATABASE dotnetcore_06_db;
# Out:
# Commands completed successfully.
# Total execution time: 00:00:00.335

# %%
USE dotnetcore_06_db;

CREATE TABLE Users (
  Id INT PRIMARY KEY IDENTITY(1,1) NOT NULL,
  Name VARCHAR(50),
  Password VARCHAR(50)
);
# Out:
# Commands completed successfully.
# Total execution time: 00:00:00.013

# %%
USE dotnetcore_06_db;

INSERT INTO Users (Name, Password)
VALUES ('admin', '$2a$12$qhx/EbF0qos4iQgSqdoxNOD.XHzVXOY29g2KbAiZqHolswA.d7KLC');
# Out:
# Msg 2628, Level 16, State 1, Line 3
# String or binary data would be truncated in table 'dotnetcore_06_db.dbo.Users', column 'Password'. Truncated value: '$2a$12$qhx/EbF0qos4iQgSqdoxNOD.XHzVXOY29g2KbAiZqHo'.
# The statement has been terminated.
# Total execution time: 00:00:00.006
